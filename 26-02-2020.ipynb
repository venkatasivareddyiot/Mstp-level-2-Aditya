# %% [markdown]
# ## File Handling

# %% [raw]
# open(filename,mode)

# %%
f = open("DataFiles/data.txt")
data = f.read()
print(data)
f.close()
# Out:
# Aditya Engineering college
# APSSDC
# Python Programming

# %%
with open("DataFiles/data.txt","r") as f:
    data = f.read()
    print(data)
# Out:
# Aditya Engineering college
# APSSDC
# Python Programming

# %%
with open("DataFiles/data1.txt","w") as f:
    f.write("This is txt file.")

# %%
with open("DataFiles/data1.txt","a") as f:
    f.write("\nChecking difference")

# %%
with open("DataFiles/data1.txt","a+") as f:
    f.read()
    print(f.tell())
    print(f.seek(5))
    print(f.read(6))
# Out:
# 17
# 5
# is txt

# %%
"python@program workshop@".split("@")
# Out:
# ['python', 'program workshop', '']

# %%
with open("DataFiles/data.txt","r") as f:
    data = f.readlines()
    for i in data:
        print(i)
# Out:
# Aditya Engineering college
#
# APSSDC
#
# Python Programming

# %%
Write a python program to  read a file line by
line and store it into a list.

# %% [markdown]
# ## File Data Processing

# %%
def readfile(filename):
    with open(filename,"r") as f:
        filedata = f.read()
    return filedata
print(readfile("DataFiles/data.txt"))
# Out:
# Aditya Engineering college
# APSSDC
# Python Programming

# %%
def FileToList(filename):
    with open(filename,"r") as f:
        filedata = f.read()
        lines = filedata.split('\n')
    return lines
print(FileToList("DataFiles/data.txt"))
# Out:
# ['Aditya Engineering college', 'APSSDC', 'Python Programming']

# %%
# Counting the number of lines in a text file
def linecount(filename):
    count = 0
    with open(filename,"r") as f:
        for i in f:
            count+=1
    return count
linecount("DataFiles/data.txt")
# Out:
# 3

# %%
- Words count
- Characters Count
- unique word count

- kth largest number in a list using functions.
- print the element with kth highest frequency in
a list
- print the third smallest frequency element in a
list.
