# %% [markdown]
# ## Tuple

# %%
t1 = (1,2,3)
t1
# Out:
# (1, 2, 3)

# %%
t1[0]
# Out:
# 1

# %%
t1[-1]
# Out:
# 3

# %%
t2 = ("one","two","three")
for item in t2:
    print(item)
# Out:
# one
# two
# three

# %%
t3  = t1+t2
t3
# Out:
# (1, 2, 3, 'one', 'two', 'three')

# %%
if "four" in t3:
    print(True)
print(False)
# Out:
# False

# %%
t3[2:5]
# Out:
# (3, 'one', 'two')

# %%
t3[-4:-1]
# Out:
# (3, 'one', 'two')

# %%
t = ("aditya",)
type(t)
# Out:
# tuple

# %%
t4 = ("python","java","Program")
li = list(t4)
li[2] = "c++"
print(tuple(li))
# Out:
# ('python', 'java', 'c++')

# %%
del t2

# %%
for i in t2:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2198fe53ed88> in <module>
# ----> 1 for i in t2:
#       2     print(i)
#
# NameError: name 't2' is not defined

# %%
tu = ()
for i in tu:
    print(i)

# %%
t3 = (2,3,7,6,7,14,10,14,2,6,31)
t3.count(2)
# Out:
# 2

# %%
t3.index(7)
# Out:
# 2

# %%
t3.index(7,3)
# Out:
# 4

# %%
t = 1,2,3,4
type(t)
# Out:
# tuple

# %%
t1,t2,t3,t4 = t
t1
# Out:
# 1

# %%
t2
# Out:
# 2

# %%
t3
# Out:
# 3

# %%
t4
# Out:
# 4

# %% [markdown]
# ### Tasks on Tuples

# %% [raw]
# - 1) Write a python to change the item in a tuple.
# - 2) Write a python program to convert a tuple to a string
# - 3) Print the 4th element and 4th element from the last in a tuple
# - 4) Write a program to find the repeated items in a tuple
# - 5) Print the length of a tuple without using length function.
# - 6) Write a program to reverse a tuple
# - 7) Write a program to replace the last value of all elements in a tuple

# %% [markdown]
# ## Tasks on Lists

# %% [raw]
# - 1) Write a program to find the second largest and second smallest elements in a list
# - 2) Write a program to get the difference between two lists
# - 3) Write a program to print the list after removing even numbers in it
# - 4) Print the palindromic elements in a given list.

# %%
tu = ((1,2,3),(2,3,4),(4,5,6))
for i in tu:
    print(i[:-1]+(10,))
# Out:
# (1, 2, 10)
# (2, 3, 10)
# (4, 5, 10)

# %%
li = 10,3,4,7,-1,2,0
sali = -1 0 2 3 4 7 10

1st largest  -1
2nd largest  -2
.
.
.
.
kth largest -k



1st smallest   0
2nd smallest   1
3rd smallest   2
.
.
.
.
kth smallest  k-1

# %%
list is in descending order
1,3,2,5,6,3,1,5
