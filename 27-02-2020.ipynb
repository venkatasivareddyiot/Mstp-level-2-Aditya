# %% [markdown]
# ### map functions
# ### lamda functions
# ### filter

# %%
 def even(n):
        if(n%2==0):
            return True
        return False

# %%
def square(n):
    return n**2

# %%
a=int(input("enter lower boundary"))
b=int(input("enter upper boundary"))
li=[]
for i in range(a,b+1):
    c=square(i)
    if(even(c)):
        li.append(c)
print(li)
# Out:
# enter lower boundary2
# enter upper boundary3
# [4]

# %%
print(list(map(even,range(int(input("enter lb")),(int(input("enter ub")))))))
# Out:
# enter lb2
# enter ub32
# [True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False]

# %%
li=[1,2,3,4,5,6,7,8,9]

# %%
print(list(map(square,[4])))
# Out:
# [16]

# %%
def prime(n):
    count=0
    if(n==2):
        return True
    for i in range(2,int(n/2)+1):
        if(n%i==0):
            count+=1
    if(count==0):
        return True
    return False

# %%
prime(9)
# Out:
# False

# %%
cub=lambda x:((x**2)+(2*x))+3

# %%
cub(2)
# Out:
# 11

# %%
squ=lambda x:x**2

# %%
eve=lambda x:x**2
print(list(map(eve,range(int(input("lb")),int(input("ub"))+1))))
# Out:
# lb2
# ub7
# [4, 9, 16, 25, 36, 49]

# %%
list(filter(even,li))
# Out:
# [4]

# %%
list(filter(even,list(map(squ,range))))
# Out:
# [4, 16, 36, 64]

# %% [markdown]
#  #### print list of  all prime no's which are starting with '4' in a given range
